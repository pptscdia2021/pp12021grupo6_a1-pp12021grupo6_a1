# %%
# Instalar pymysql para poder conectarnos desde Python, si es necesario
#pip install pymysql

# %%
#Realizar la conexion a la BBDD employees
#Colocar Password correspondiente antes de ejecutar

import pymysql
try:
	conexion = pymysql.connect(host='localhost',
                             user='root',
                             password='********',
                             db='employees')
	print("Conexión correcta")
except (pymysql.err.OperationalError, pymysql.err.InternalError) as e:
	print("Ocurrió un error al conectar: ", e)
# Out:
# Conexión correcta

# %%
#Obtenemos los datos de la tabla employees
#Colocar Password correspondiente antes de ejecutar

import pymysql
try:
    conexion = pymysql.connect(host='localhost',
                             user='root',
                             password='**********',
                             db='employees')
    try:
        with conexion.cursor() as cursor:
            # En este caso no necesitamos limpiar ningún dato
            # Para probar, agregar al final de la sentencia SQL, por ejemplo, LIMIT 100
            cursor.execute("SELECT * FROM employees;")
 
            # Con fetchall traemos todas las filas
            employees = cursor.fetchall()
 
            # Recorrer e imprimir
            for emp in employees:
                print(emp)
    finally:
        conexion.close()
    
except (pymysql.err.OperationalError, pymysql.err.InternalError) as e:
    print("Ocurrió un error al conectar: ", e)

# %%
#Obtenemos los datos de la tabla employees
#Colocar Password correspondiente antes de ejecutar
import pymysql
try:
    conexion = pymysql.connect(host='localhost',
                             user='root',
                             password='********',
                             db='employees')
    try:
        with conexion.cursor() as cursor:
            # En este caso no necesitamos limpiar ningún dato
            # Para probar, agregar al final de la sentencia SQL, por ejemplo, LIMIT 100
            cursor.execute("SELECT * FROM employees;")
 
            # Con fetchall traemos todas las filas
            employees = cursor.fetchall()
 
            # Recorrer e imprimir
            for emp in employees:
                print(emp)
    finally:
        conexion.close()
    
except (pymysql.err.OperationalError, pymysql.err.InternalError) as e:
    print("Ocurrió un error al conectar: ", e)
# Out:
# (1000, datetime.date(1985, 1, 1), 'Pepe', 'Pe', 'M', datetime.date(1985, 1, 1))
# (10001, datetime.date(1953, 9, 2), 'Georgi', 'Facello', 'M', datetime.date(1986, 6, 26))
# (10002, datetime.date(1964, 6, 2), 'Bezalel', 'Simmel', 'F', datetime.date(1985, 11, 21))
# (10003, datetime.date(1959, 12, 3), 'Parto', 'Bamford', 'M', datetime.date(1986, 8, 28))
# (10004, datetime.date(1954, 5, 1), 'Chirstian', 'Koblick', 'M', datetime.date(1986, 12, 1))
# (10005, datetime.date(1955, 1, 21), 'Kyoichi', 'Maliniak', 'M', datetime.date(1989, 9, 12))
# (10006, datetime.date(1953, 4, 20), 'Anneke', 'Preusig', 'F', datetime.date(1989, 6, 2))
# (10007, datetime.date(1957, 5, 23), 'Tzvetan', 'Zielinski', 'F', datetime.date(1989, 2, 10))
# (10008, datetime.date(1958, 2, 19), 'Saniya', 'Kalloufi', 'M', datetime.date(1994, 9, 15))
# (10009, datetime.date(1952, 4, 19), 'Sumant', 'Peac', 'F', datetime.date(1985, 2, 18))
# ...

# %%
#Obtenemos los datos de la tabla employees que sean mujeres
#Colocar Password correspondiente antes de ejecutar

import pymysql
try:
    conexion = pymysql.connect(host='localhost',
                             user='root',
                             password='********',
                             db='employees')
    try:
        with conexion.cursor() as cursor:
            #Para probar, agregar al final de la sentencia SQL, por ejemplo, LIMIT 100
            consulta = "SELECT emp_no, last_name FROM employees WHERE gender ='F' ;"
            cursor.execute(consulta)
 
            # Con fetchall traemos todas las filas
            employees = cursor.fetchall()
 
            # Recorrer e imprimir
            for emp in employees:
                print(emp)
    finally:
        conexion.close()
    
except (pymysql.err.OperationalError, pymysql.err.InternalError) as e:
    print("Ocurrió un error al conectar: ", e)
# Out:
# (10002, 'Simmel')
# (10006, 'Preusig')
# (10007, 'Zielinski')
# (10009, 'Peac')
# (10010, 'Piveteau')
# (10011, 'Sluis')
# (10017, 'Bouloucos')
# (10018, 'Peha')
# (10023, 'Montemayor')
# (10024, 'Pettey')
# (10027, 'Reistad')
# (10032, 'Reistad')
# (10040, 'Meriste')
# (10041, 'Lenart')
# (10042, 'Stamatiou')
# (10044, 'Casley')
# (10049, 'Tramer')
# (10053, 'Zschoche')
# (10056, 'Bernini')
# (10057, 'Callaway')
# (10059, 'McAlpine')
# (10063, 'Leonhardt')
# (10069, 'Bierman')
# (10072, 'Sidou')
# (10074, 'Bernatsky')
# (10075, 'Dolinsky')
# (10076, 'Ritzmann')
# (10078, 'Mondadori')
# (10079, 'Gils')
# (10087, 'Eugenio')
# (10088, 'Syrzycki')
# (10089, 'Flasterstein')
# (10092, 'Niizuma')
# (10094, 'Ossenbruggen')
# (10098, 'Servieres')
# (10099, 'Sullins')
# (10100, 'Haraldson')
# (10101, 'Heyers')
# (10102, 'Luby')
# (10107, 'Baca')
# (10109, 'Prampolini')
# (10110, 'Ullian')
# (10111, 'Rosis')
# (10112, 'Swick')
# (10114, 'Demeyer')
# (10116, 'Czap')
# (10117, 'Blokdijk')
# ...

# %%
#Insertamos un valor en la tabla employees
#Colocar Password correspondiente antes de ejecutar

import pymysql
try:
    conexion = pymysql.connect(host='localhost',
                             user='root',
                             password='********',
                             db='employees')
    try:
        with conexion.cursor() as cursor:

            # Como el num de empleado 1000 ya existe, busco el maximo emp_no con la sentencia
            # SELECT max(emp_no) FROM employees e inserto el siguiente:
            
            consulta = "INSERT INTO employees(emp_no, birth_date, first_name, last_name, gender, hire_date) VALUES (%s, %s, %s, %s, %s, %s);"
            
            cursor.execute(consulta, ('500000', '1985-01-01','Pepe', 'Pe','M','1985-01-01'))
            # Podemos llamar muchas veces a .execute con datos distintos
            #cursor.execute(consulta, ())
            #cursor.execute(consulta, ())
            #cursor.execute(consulta, ())
        conexion.commit()
    finally:
        conexion.close()
except (pymysql.err.OperationalError, pymysql.err.InternalError) as e:
    print("Ocurrió un error al conectar: ", e)
